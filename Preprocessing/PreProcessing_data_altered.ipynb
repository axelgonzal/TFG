# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
input_folder = "/content/drive/MyDrive/TFG/data/altered"
output_folder = "/content/drive/MyDrive/TFG/data_processed/altered_clusters"

os.makedirs(output_folder, exist_ok=True)

# %%
centers = np.array([
[-3,-3],[-3,-1],[-3,1],[-3,3],
[-1,-3],[-1,-1],[-1,1],[-1,3],
[1,-3],[1,-1],[1,1],[1,3],
[3,-3],[3,-1],[3,1],[3,3]
])

for file in os.listdir(input_folder):

    if not file.endswith(".csv"):
        continue

    print("Processing:", file)

    path = os.path.join(input_folder, file)
    df = pd.read_csv(path)

    Q = []
    X_norm = []
    Y_norm = []

    for _, row in df.iterrows():

        point = np.array([row["Real"], row["Imag"]])

        distances = np.linalg.norm(centers - point, axis=1)
        q = np.argmin(distances)

        cx, cy = centers[q]

        Q.append(q)
        X_norm.append(row["Real"] - cx)
        Y_norm.append(row["Imag"] - cy)

    df["Q"] = Q
    df["X_norm"] = X_norm
    df["Y_norm"] = Y_norm

    output_path = os.path.join(output_folder, file)
    df.to_csv(output_path, index=False)

print("Done!")
# Out:
# Processing: source_1760.csv
# Processing: source_160.csv
# Processing: source_1200.csv
# Processing: source_1600.csv
# Processing: source_400.csv
# Processing: source_80.csv
# Processing: source_240.csv
# Processing: source_1680.csv
# Processing: source_880.csv
# Processing: source_560.csv
# Processing: source_800.csv
# Processing: source_480.csv
# Processing: source_1520.csv
# Processing: source_1040.csv
# Processing: source_640.csv
# Processing: source_1120.csv
# Processing: source_720.csv
# Processing: source_1360.csv
# Processing: source_1440.csv
# Processing: source_1280.csv
# Processing: source_1920.csv
# Processing: source_1840.csv
# Processing: source_320.csv
# Processing: source_960.csv
# Done!
